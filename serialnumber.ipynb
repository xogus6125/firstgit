# %%
# # rows 에서 한줄을 받아오면 string slicing 하여 그 값을 pandas에 바로 넣는거 해보기.

from selenium import webdriver # 크롬 브라우저 뜨게하는것
from selenium.webdriver.common.keys import Keys # 키 값 넣을때 쓰는 라이브러리
from selenium.webdriver.common.by import By # 요소 찾을때 쓰는 라이브러리
from selenium.webdriver.support.ui import WebDriverWait #아래와 비슷함
from selenium.webdriver.support import expected_conditions as EC # 셀레니움 wait 중 해당 요소 뜰때까지 기다림
from selenium.webdriver.common.action_chains import ActionChains # 키 연속으로 입력하는 라이브러리
import time # 물리적으로 기다림
import urllib.request  # url 따오는 라이브러리
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import openpyxl
import csv
from urllib.request import HTTPError
import sys
from io import StringIO
import html5lib
from urllib.request import urlopen

options = webdriver.ChromeOptions()
options.add_argument('headless')
chromedriver = "C:/Users/silve/Untitled Folder/chromedriver.exe"
print("스크래핑할 날짜를 입력해주세요.")
UserInput = int(input()) # 스크래핑할 날짜
driver = webdriver.Chrome( options=options)
# driver = webdriver.Chrome()
driver.get("http://192.168.100.5:10331/gift2/gift_login.aspx")
LogID = driver.find_element(By.ID, "Login1_UserName").send_keys("event2")
LogPW = driver.find_element(By.ID, "Login1_Password").send_keys("1234")
driver.find_element(By.ID, "Login1_LoginButton").click()
print("로그인 성공...")
# 금액권 정산

driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[1]/table/tbody/tr/td/div/div/div[2]/table[3]/tbody/tr/td[4]/a").click()
dateS = driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[2]/tbody/tr/td[1]/input[1]")
dateE = driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[2]/tbody/tr/td[1]/input[3]")
dateS.clear()
dateS.send_keys(UserInput)
dateE.clear()
dateE.send_keys(UserInput)
driver.find_element(By.ID, "ContentColumn_inquiry_btn").click()
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[3]/tbody/tr/td[1]/div/table/tbody/tr[2]/td[1]/a")))
driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[3]/tbody/tr/td[1]/div/table/tbody/tr[2]/td[1]/a").click()

Data = {
    '지급일자' : [],
    'seq' : [],
    '포인트카드번호' : [],
    '시리얼번호' : [],
    '매장명' : [],
    '금액' : [],
    '승인번호' : [],
    '반품일자' : []
}


print("""
스크래핑을 시작합니다.
스크래핑 할 내역입니다.
1.No
2.지급 일자
3.seq
4.포인트카드번호
5.시리얼번호
6.매장명
7.금액
8.승인번호
9.반품일자
평균 소요시간 10~ 15초
""")

html = driver.page_source

soup = bs(html)

table = soup.find_all("table" , id="ContentColumn_GridView2")
for rows in table:
    td = rows.find_all("tr")[1:]
    for value in td:
        cols = value.find_all("td")
        Data['지급일자'].append(cols[1].text)
        Data['seq'].append(cols[3].text)
        Data['포인트카드번호'].append(cols[4].text)
        Data['시리얼번호'].append(cols[6].text)
        Data['매장명'].append(cols[7].text)
        Data['금액'].append(cols[8].text)
        Data['승인번호'].append(cols[9].text)
        Data['반품일자'].append(cols[10].text)
print("금액권 1만원권 스크래핑 완료..")

driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[1]/table/tbody/tr/td/div/div/div[2]/table[3]/tbody/tr/td[4]/a").click()
dateS = driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[2]/tbody/tr/td[1]/input[1]")
dateE = driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[2]/tbody/tr/td[1]/input[3]")
dateS.clear()
dateS.send_keys(UserInput)
dateE.clear()
dateE.send_keys(UserInput)
driver.find_element(By.ID, "ContentColumn_inquiry_btn").click()
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[3]/tbody/tr/td[1]/div/table/tbody/tr[2]/td[1]/a")))
driver.find_element(By.XPATH, "/html/body/form/table[2]/tbody/tr/td[2]/table/tbody/tr/td/table[3]/tbody/tr/td[1]/div/table/tbody/tr[3]/td[1]/a").click() # 금액권 2만원권 table 열기.

html = driver.page_source

soup = bs(html)

table1 = soup.find_all("table" , id="ContentColumn_GridView2")
print("금액권 2만원권 스크래핑 시작합니다..")
for rows1 in table1:
    td1 = rows1.find_all("tr")[1:]
    for value1 in td1:
        cols1 = value1.find_all("td")
        Data['지급일자'].append(cols1[1].text)
        Data['seq'].append(cols1[3].text)
        Data['포인트카드번호'].append(cols1[4].text)
        Data['시리얼번호'].append(cols1[6].text)
        Data['매장명'].append(cols1[7].text)
        Data['금액'].append(cols1[8].text)
        Data['승인번호'].append(cols1[9].text)
        Data['반품일자'].append(cols1[10].text)
print("금액권 2만원권 스크래핑 종료.")
print("데이터 분석중...")
df = pd.DataFrame(Data)

csvfile = "C:/Users/silve/OneDrive/바탕 화면/kakaoplus/" + str(UserInput) + ".csv"

seq = df['seq'] == str('1') # seq라는 변수에 seq행의 1값과 동일한 아이들만 넣음.
seq_one = df[seq] # 데이터프레임에 seq 변수를 넣은 값
re_count = seq_one['반품일자'].str.contains('\xa0') # 반품일자에 문자열 contains(일부를 포함하는) 값('\xa0')을 re_count에 넣는다.
take_back = seq_one[~re_count] # re_count(반품일자) 스페이스 값을 포함하지 않는 (~변수 는 반대의 값이다.) 데이터를 seq_one에 합친다.

print(str(UserInput) + "일 반출된 모든 금액권(반품 포함)은 " + str(len(seq_one)) + " 장입니다.")

display("반품은 " + str(len(take_back)) +  " 장입니다.") # display 해줘 "반품은 " + 문자열(길이(반품일자 장수)) + " 장입니다."

display("반품을 뺀 금액권 개수는 " + str(len(seq_one) - len(take_back)) + " 장 입니다.")

# 여기에 로스 수식 넣기.
last_data = seq_one.sort_values(by = '시리얼번호', ascending = True) # 오름차순 정렬하는 명령어. ascending=False는 오름차순 True는 내림차순

last_data.to_csv(csvfile, encoding='UTF-8-sig')
print(str(UserInput) + " 일자의 csv파일을 저장하였습니다. 바탕화면의 kakaoplus 폴더를 확인하세요")
# Out:
# 스크래핑할 날짜를 입력해주세요.
# 20220911
# 로그인 성공...
#
# 스크래핑을 시작합니다.
# 스크래핑 할 내역입니다.
# 1.No
# 2.지급 일자
# 3.seq
# 4.포인트카드번호
# 5.시리얼번호
# 6.매장명
# 7.금액
# 8.승인번호
# 9.반품일자
# 평균 소요시간 10~ 15초
#
# 금액권 1만원권 스크래핑 완료..
# 금액권 2만원권 스크래핑 시작합니다..
# 금액권 2만원권 스크래핑 종료.
# 데이터 분석중...
# 20220911일 반출된 모든 금액권(반품 포함)은 940 장입니다.
# '반품은 16 장입니다.'
# '반품을 뺀 금액권 개수는 924 장 입니다.'
# 20220911 일자의 csv파일을 저장하였습니다. 바탕화면의 kakaoplus 폴더를 확인하세요

# %% [markdown]
# # 로스 찾는것 마지막으로 해보자.

# %%
import pandas as pd
import numpy as np
# dfa, dfb 숫자에 모든공백 제거(완료.)
# dropna는 NaN 데이터 삭제해주는것. axis는 데이터 프레임의 방향임. 0은 열방향, 1은 행방향
# 시작번호 열을 만들었음 이름은 dfa
dfs = pd.read_excel("C:/Users/silve/OneDrive/바탕 화면/금액권 입출고대장.xlsx")
dfa = dfs['Unnamed: 1'][3:].dropna(axis=0)
dfa.reset_index(drop=True, inplace=True)
dfa = dfa.str.replace(' ', '')


# 끝번호 열 만듬 이름은 dfb
# dfb는 dfb에서 문자열 공백을 없애서 넣는다.
dfb = dfs['Unnamed: 2'][3:].dropna(axis=0)
dfb.reset_index(drop=True, inplace=True)
dfb = dfb.str.replace(' ', '')


# 수량 열 만듬 이름은 dfc 이걸로 수량 int값의 len만큼 시리얼번호 데이터프레임 해당 값을 비교하고 틀리면 개수와 해당 번호 반환.
dfc = dfs['Unnamed: 3'][3:].dropna(axis=0)
dfc.reset_index(drop=True, inplace=True)

# 근무자 열 만듬. 이름은 dfd 이걸로 틀린거 찾으면 이름까지 반환해보기. ex: 1~100 틀린값을 찾으면 그 값의 제일 첫번째가 인덱스 몇번인지. 근무자이름 나타내기.
dfd = dfs['Unnamed: 4'][3:].dropna(axis=0)
dfd.reset_index(drop=True, inplace=True)

# 반납 시작번호 열 만듬 이름은 dfe 이걸로 만약에 해당열에 dfa나 dfb가 값이 있으면 무시하고 반납만 진행하는걸로.
# 반납 떠올때 dropna하면 안되고 기준을 dfa의 index값으로 잡아서 해당 수량만큼 떠오기.(그냥 NaN 값을 없애는 걸로 방향을 잡았음. 샾이나 0으로 채울거임.)
dfe = dfs['Unnamed: 6'][3:].dropna(axis=0)
dfe.reset_index(drop=True, inplace=True)
dfe = dfe.str.replace(' ', '')

# 반납 끝번호 열 만듬.
dff = dfs['Unnamed: 7'][3:].dropna(axis=0)
dff.reset_index(drop=True, inplace=True)
dff = dff.str.replace(' ', '')

# 반납 수량 만듬. 이름은 dfg
dfg = dfs['Unnamed: 8'][3:].dropna(axis=0)
dfg.reset_index(drop=True, inplace=True)

# 데이터 리스트 만들어서 열 데이터 넣음.
data = []
data.append(dfa)
data.append(dfb)
data.append(dfc)
data.append(dfd)
data.append(dfe)
data.append(dff)
data.append(dfg)

# 데이터 프레임을 만들었습니다. concat은 더해주는 함수임. axis는 방향이고 데이터를 오른쪽으로 정렬한다는 뜻.
df = pd.concat([dfa, dfb, dfc, dfd, dfe, dff, dfg], axis = 1)
df.rename(columns={"Unnamed: 1": "시작번호", "Unnamed: 2": "끝번호", "Unnamed: 3": "수량", "Unnamed: 4": "근무자", "Unnamed: 6": "반납 시작번호", "Unnamed: 7": "반납 끝번호", "Unnamed: 8": "반납수량"}, inplace=True)

C = [] # C 리스트에는 끝번호 + 1 한 값 넣어서 다시 붙여넣기할거임.
D = [] # 이건 아직 쓸모없음.

df_sharp = df['반납 시작번호'] == '#'
Spend = df[df_sharp] # 반납없이 끝까지 금액권 나간거
Spend = Spend[['시작번호','끝번호','수량', '근무자']] # 이거는 금액권 다 안나간 수량을 뺀 값.
for i in Spend['끝번호']:
    C.append(int(i) + int(1))
Spend['끝번호'] = C # Spend['끝번호'] = C # 끝번호에서 + 1한 값을 넣었음.

B1 = df['반납 시작번호'] != '#'
B1 = df[B1]
B1 = B1[['시작번호', '반납 시작번호', '반납수량']]
B1.rename(columns = {'반납 시작번호' : 'key', '반납수량' : 'key1'}, inplace = True)

# 시작번호랑 반납 시작번호랑 반납 수량 넣었음.
# for 루프를 만들거임. Spend의 index길이만큼 반복해서 배열 만들거임.

df1 = df[['시작번호', '끝번호', '수량']]
df1.rename(columns = {'끝번호' : 'key', '수량' : 'key1'}, inplace = True)

df2 = df[['반납 시작번호', '반납 끝번호', '반납수량']]
df2.rename(columns = {'반납 시작번호' : 'key', '반납수량' : 'key1'}, inplace = True)
Spend.rename(columns = {'끝번호' : 'key', '수량' : 'key1'})
compare_df = np.where(Spend == df2, True, False)
print(compare_df)

# pd.merge(df1, df2, on='key', how='left')
# print("금액권 명단의 총 수량은 " + )
# for i in Spend_index():
    
# 시작번호와 끝번호 한 열을 가지고와서 int로 만든다음, range로 배열로 만들기. 그것을 람다로 바로 시리얼번호와 대조해서 같으면 지우기. 다르면 반환.
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17892\4074553436.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = {'끝번호' : 'key', '수량' : 'key1'}, inplace = True)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17892\4074553436.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns = {'반납 시작번호' : 'key', '반납수량' : 'key1'}, inplace = True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 80>()
#      78 df2.rename(columns = {'반납 시작번호' : 'key', '반납수량' : 'key1'}, inplace = True)
#      79 Spend.rename(columns = {'끝번호' : 'key', '수량' : 'key1'})
# ---> 80 compare_df = np.where(Spend == df2, True, False)
#      81 print(compare_df)
#
# File C:\anaconda\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File C:\anaconda\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File C:\anaconda\lib\site-packages\pandas\core\frame.py:6931, in DataFrame._cmp_method(self, other, op)
#    6928 def _cmp_method(self, other, op):
#    6929     axis = 1  # only relevant for Series other case
# -> 6931     self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    6933     # See GH#4537 for discussion of scalar op behavior
#    6934     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File C:\anaconda\lib\site-packages\pandas\core\ops\__init__.py:289, in align_method_FRAME(left, right, axis, flex, level)
#     287             left, right = left.align(right, join="outer", level=level, copy=False)
#     288         else:
# --> 289             raise ValueError(
#     290                 "Can only compare identically-labeled DataFrame objects"
#     291             )
#     292 elif isinstance(right, ABCSeries):
#     293     # axis=1 is default for DataFrame-with-Series op
#     294     axis = left._get_axis_number(axis) if axis is not None else 1
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
countall = df['반납수량'] > 0
countall = df[countall]
recount1 = countall['반납수량']
countall['수량'].apply(recount1)
countall
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [91], in <cell line: 4>()
#       2 countall = df[countall]
#       3 recount1 = countall['반납수량']
# ----> 4 countall['수량'].apply(recount1)
#       5 countall
#
# File C:\anaconda\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply(self)
#    1074 # dispatch to agg
#    1075 if is_list_like(self.f):
# -> 1076     return self.apply_multiple()
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:557, in Apply.apply_multiple(self)
#     548 def apply_multiple(self) -> DataFrame | Series:
#     549     """
#     550     Compute apply in case of a list-like or dict-like.
#     551
#    (...)
#     555         Result when self.f is a list-like or dict-like, None otherwise.
#     556     """
# --> 557     return self.obj.aggregate(self.f, self.axis, *self.args, **self.kwargs)
#
# File C:\anaconda\lib\site-packages\pandas\core\series.py:4303, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4300     func = dict(kwargs.items())
#    4302 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4303 result = op.agg()
#    4304 return result
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:1085, in SeriesApply.agg(self)
#    1084 def agg(self):
# -> 1085     result = super().agg()
#    1086     if result is None:
#    1087         f = self.f
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:472, in Apply.agg_dict_like(self)
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#     471     colg = obj._gotitem(selection, ndim=1)
# --> 472     results = {key: colg.agg(how) for key, how in arg.items()}
#     473 else:
#     474     # key used for column selection and output
#     475     results = {
#     476         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     477     }
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:472, in <dictcomp>(.0)
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#     471     colg = obj._gotitem(selection, ndim=1)
# --> 472     results = {key: colg.agg(how) for key, how in arg.items()}
#     473 else:
#     474     # key used for column selection and output
#     475     results = {
#     476         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     477     }
#
# File C:\anaconda\lib\site-packages\pandas\core\series.py:4303, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4300     func = dict(kwargs.items())
#    4302 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4303 result = op.agg()
#    4304 return result
#
# File C:\anaconda\lib\site-packages\pandas\core\apply.py:1091, in SeriesApply.agg(self)
#    1088 kwargs = self.kwargs
#    1090 # string, list-like, and dict-like are entirely handled in super
# -> 1091 assert callable(f)
#    1093 # we can be called from an inner function which
#    1094 # passes this meta-data
#    1095 kwargs.pop("_level", None)
#
# AssertionError:
